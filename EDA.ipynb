# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Data

# %%
df = pd.read_csv(f"Dataset\ecommerce_fraud_dataset.csv")
df_u = df.copy()

# %%
display(df)
print(f'jumlah row: {df.shape[0]}\njumlah column: {df.shape[1]}')
# Out:
#        Transaction_ID  Transaction_Amount  Quantity  Customer_Age  \
# 0              100000              140.78         5            32
# 1              100001               50.89         3            40
# 2              100002              275.72         3            39
# 3              100003              836.87         2            38
# 4              100004                2.13         1            44
# ...               ...                 ...       ...           ...
# 29995          129995              213.44         2            55
# 29996          129996              638.15         2            34
# 29997          129997              379.93         2            50
# 29998          129998              357.57         3            22
# 29999          129999              304.45         1            52
#
#        Account_Age_Days  Transaction_Hour Product_Category Payment_Method  \
# 0                   107                 7            Books    Credit Card
# ...

# %%
df.info()
display(df.describe())
display(df.describe(include=['O']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Transaction_ID               30000 non-null  int64
#  1   Transaction_Amount           30000 non-null  float64
#  2   Quantity                     30000 non-null  int64
#  3   Customer_Age                 30000 non-null  int64
#  4   Account_Age_Days             30000 non-null  int64
#  5   Transaction_Hour             30000 non-null  int64
#  6   Product_Category             30000 non-null  object
#  7   Payment_Method               30000 non-null  object
#  8   Device_Used                  30000 non-null  object
#  9   Address_Match                30000 non-null  object
#  10  Is_Fraud                     30000 non-null  int64
#  11  Customer_ID                  30000 non-null  object
#  12  Transaction_Time             30000 non-null  object
# ...

# %% [markdown]
# - Need to know the time range of the data
# - Need to know the data distribution
# - Then analyze the data

# %%
## convert object to timestamp
df_u["Transaction_Time"] = pd.to_datetime(df_u["Transaction_Time"])
rtime = df_u['Transaction_Time'].describe()
display(rtime)
print(f'range time: {rtime['min']} - {rtime['max']}')
# Out:
# count                            30000
# mean     2026-01-27 16:40:16.872000256
# min                2025-12-23 23:43:43
# 25%                2026-01-10 10:03:28
# 50%                2026-01-27 16:29:43
# 75%                2026-02-14 00:17:13
# max                2026-03-03 10:13:43
# Name: Transaction_Time, dtype: object
# range time: 2025-12-23 23:43:43 - 2026-03-03 10:13:43
